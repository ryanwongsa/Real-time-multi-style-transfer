# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import torch
from torchvision import transforms
from inference.Inferencer import Inferencer
from models.PasticheModel import PasticheModel
from PIL import Image
import cv2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
num_styles = 16
image_size = 512
mean = [0.485, 0.456, 0.406]
std=[0.229, 0.224, 0.225]
model_save_dir = "style16/pastichemodel-FINAL.pth"
transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
                             std=std)
    ])

pastichemodel = PasticheModel(num_styles)

# %%
inference = Inferencer(pastichemodel,transform,device)
inference.load_model_weights(model_save_dir)

# %%
im = Image.open("../profile.jpg").convert('RGB')

# %%
# %time inference.eval_image(im, 0,1,1.0)
# Out:
# Wall time: 157 ms
# <PIL.Image.Image image mode=RGB size=716x512 at 0x13F142B5278>

# %%
# %time inference.eval_image(im, 2,1,0.0)
# Out:
# Wall time: 143 ms
# <PIL.Image.Image image mode=RGB size=716x512 at 0x13F142B5CF8>
